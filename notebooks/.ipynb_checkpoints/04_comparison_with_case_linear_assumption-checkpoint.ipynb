# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import os
import sys
sys.path.append('../')

# %%
from model import UnicycleModel
from cost import UnicycleCost
from constraints import UnicycleConstraints
from scipy.integrate import solve_ivp
from matplotlib.patches import Ellipse
from utils.utils_alg import get_neighbor_vec,get_K_discrete
from utils.utils_plot import plot_traj,plot_traj_set,plot_state_input
from Single_PTR import Single_PTR
from PTR import PTR
from utils.utils_alg import get_sample_eta_w,propagate_model
import cvxpy as cvx
from scipy.integrate import solve_ivp
from EstimatingLipschitz import Lipschitz
from LMI import Q_update
# Out:
# (CVXPY) Nov 03 10:57:08 PM: Encountered unexpected exception importing solver SCS:
# ImportError("dlopen(/opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib\n  Referenced from: /opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so\n  Reason: tried: '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file)")

# %%
ix = 3
iu = 2
iw = 2
iq = 2
ip = 2
N = 30
tf = 3
delT = tf/N

# %%
# time-invariant matrices
C = np.array([[0,0,1],[0,0,0]])
D = np.array([[0,0],[1,0]])
E = np.array([[1,0],[0,1],[0,0]])
G = np.zeros((iq,iw))

# %% [markdown]
# ## obstacle setting

# %%
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])
# obstacle
c_list = []
H_list = []
c1 = [1,2]
H1 = get_H_obs(0.75,1.5)
c_list.append(c1)
H_list.append(H1)
c2 = [4,3]
H2 = get_H_obs(0.75,1.5)
c_list.append(c2)
H_list.append(H2)

# %% [markdown]
# ## initial and final conditions

# %%
xi = np.zeros(3)
xi[0] = 0.0
xi[1] = 0.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0

Qini = np.diag([0.4**2,0.4**2,np.deg2rad(20)**2])
Qf = np.diag([0.5**2,0.5**2,np.deg2rad(20)**2])*1.5



myModel = UnicycleModel.unicycle('Hello',ix,iu,iw,'numeric_central')
myCost = UnicycleCost.unicycle('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu)
myConst.set_obstacle(c_list,H_list)

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
u0 = np.zeros((N+1,iu))

# %%
A,B,s,z,x_prop_n = myModel.diff_discrete_zoh(x0[0:N,:],u0[0:N,:],delT,tf) 
S = np.eye(ix)
R = 1*np.eye(iu)
K0 = get_K_discrete(A,B,S,R,S,N,ix,iu)
Q0 = np.tile(np.diag([0.35**2,0.35**2,np.deg2rad(10)**2]),(N+1,1,1))
Y0 = K0@Q0[:N]
betahat = np.ones(N+1)

# %%
plt.figure(0,figsize=(7,7))
plot_traj_set(x0,u0,c_list,H_list,Q0,xi=xi,xf=xf,Qi=Qini,Qf=Qf,plt=plt)

# %% [markdown]
# ## choose sample points

# %%
num_sample = 100
zs_sample = [] # sample in unit sphere will be projected to ellipse (Q_k)
zw_sample = [] 
    
# uniformly fixed
for i in np.linspace(-1.0, 1.0, num=5) :
    for j in np.linspace(-1.0, 1.0, num=5) :
        for k in np.linspace(-1.0, 1.0, num=4) :
            z = np.array([i,j,k])
            zs = z / np.linalg.norm(z)
            zs_sample.append(zs)
for i in np.linspace(-1.0, 1.0, num=10) :
    for j in np.linspace(-1.0, 1.0, num=10) :
        z = np.array([i,j])
        zw = z / np.linalg.norm(z)
        zw_sample.append(zw)

# %% [markdown]
# ## run

# %%
history = []
total_iter = 50
tol_funnel = 1e-8
tol_traj = 1e-8
flag_nonlinearity = False

print("STEP 0 : Start")
for idx_iter in range(total_iter) :
    print("====================================================")
    if idx_iter == 0 :
        xhat,uhat,Qhat,Yhat,Khat = x0,u0,Q0,Y0,K0
    
    print("STEP 1 : Nominal trajectory update")
    traj_solver= Single_PTR('unicycle',N,tf,1,myModel,myCost,myConst,
              w_c=1,w_vc=1e3,w_tr=1e1,tol_vc=1e-6,tol_tr=1e-4,verbosity=False)
    _,_,xnew,unew,total_num_iter,flag_boundary,traj_cost,traj_vc,traj_tr = traj_solver.run(xhat,uhat,xi,xf,Qhat,Khat)

    # discretization
    A,B,F,s,z,x_prop_n = myModel.diff_discrete_zoh_noise(xnew,unew,np.zeros((N,iw)),delT,tf) 
    sz = tf*s + z
    # propagation
    xprop,_ = traj_solver.forward_multiple(xnew,unew)
    e_prop = np.linalg.norm(xprop - xnew[1:],axis=1)
    
    print("STEP 2 : Lipschitz constant estimation")
    myM = Lipschitz(ix,iu,iq,ip,iw,N)
    myM.initialize(xnew,unew,xprop,Qhat,Khat,A,B,C,D,E,F,G,myModel,zs_sample,zw_sample)
    gamma = myM.update_lipschitz_norm(myModel,delT)
#     gamma = myM.update_lipschitz_parallel(myModel,delT)
    print("mean of gamma",np.mean(gamma,0),"max of gamma",np.max(gamma,0),"var of gamma",np.var(gamma,0))

    print("STEP 3 : Funnel update via SDP")
    funl_solver = Q_update(ix,iu,iq,ip,iw,N,delT,myCost.S,myCost.R,w_tr=1e-3)
    funl_solver.initialize(xnew,unew,A,B,C,D,E,F,G)
    
    alpha = 0.95
    Qnew,Knew,Ynew,status,funl_cost = funl_solver.solve(alpha,gamma,Qini,Qf,Qhat,Yhat,flag_nonlinearity=flag_nonlinearity)
#     print("LMI status:" + status)
    
    print("STEP 4 : update beta for invariance")
    betanew = funl_solver.update_beta(Qnew,Knew,gamma,alpha)
    for i in range(N+1) :
        Qnew[i] = Qnew[i] * betanew[i]
#     print("beta max {:}".format(np.max(betanew)))


    # measure the difference
    xdiff = np.sum(np.linalg.norm(xhat-xnew,axis=1)**2)
    udiff = np.sum(np.linalg.norm(uhat-unew,axis=1)**2)
    Qdiff = np.sum(np.array([np.linalg.norm(Qhat[i]-Qnew[i],ord='fro') for i in range(N+1)])**2)
    Kdiff = np.sum(np.array([np.linalg.norm(Khat[i]-Knew[i],ord='fro') for i in range(N)])**2)
    Ydiff = np.sum(np.array([np.linalg.norm(Yhat[i]-Ynew[i],ord='fro') for i in range(N)])**2)
    betadiff = np.linalg.norm(betanew-betahat)
    
    # update trajectory
    xhat = xnew
    uhat = unew
    Qhat = Qnew
    Khat = Knew
    Yhat = Ynew
    betahat = betanew
    
    # save trajectory
    traj = {}
    traj['x'] = xhat
    traj['u'] = uhat
    traj['Q'] = Qhat
    traj['Y'] = Yhat
    traj['K'] = Khat
    traj['gamma'] = gamma
    traj['traj_diff'] = xdiff + udiff
    traj['funl_diff'] = Qdiff + Kdiff
    traj['beta_diff'] = betadiff
    history.append(traj)
    
    print("iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta")
    print("%4d %11.3f %11.3f %8.3g %13.3g %13.3g %6.3f %10.3f %8.3g" % ( idx_iter+1,
                        traj_cost,funl_cost,traj_vc,
                        traj['traj_diff'],traj['funl_diff'],
                        np.max(e_prop),
                        np.mean(gamma,0),
                        np.max(betanew),
                        ))

    
    
    if traj['traj_diff'] < tol_traj and traj['funl_diff'] < tol_funnel :
        print("SUCCESS")
        break
    else :
        print("Accept the step")
# Out:
# STEP 0 : Start
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.016180136770726324 max of gamma 0.01805892400663157 var of gamma 3.843245017519871e-06
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    1      86.009      11.479        5           114           605  1.874      0.016     1.19
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.019098080726038916 max of gamma 0.05448142478486351 var of gamma 8.973355247617154e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    2     176.139      10.122   0.0995           153           521  0.235      0.019     1.45
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.022471010240148765 max of gamma 0.05607960664850912 var of gamma 0.00016848914937179623
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    3     214.265       8.799 7.34e-10          88.6           301  0.162      0.022     1.38
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.018468083292403792 max of gamma 0.031319887483346624 var of gamma 4.708595050203652e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    4     225.948       9.909 5.23e-11          27.9           131  0.049      0.018     1.31
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01878960958385308 max of gamma 0.0366698785461305 var of gamma 8.467502730580833e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    5     239.529       9.532 8.08e-10          3.82          3.78  0.002      0.019     1.35
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01842387896898483 max of gamma 0.03753193732350311 var of gamma 8.834393087421163e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    6     242.199       9.555 2.24e-11         0.604         0.493  0.001      0.018     1.37
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.018074957322892486 max of gamma 0.03772325150346392 var of gamma 9.499329140903064e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    7     241.134       9.493  3.8e-10         0.299        0.0665  0.000      0.018     1.37
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017878011899833963 max of gamma 0.03744886961047342 var of gamma 9.503003883570561e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    8     240.404       9.488 4.27e-11        0.0977        0.0269  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017834485096584758 max of gamma 0.03745457594181444 var of gamma 9.480199063887519e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#    9     240.210       9.480 2.75e-10        0.0264        0.0073  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017807626668755672 max of gamma 0.03745641662408077 var of gamma 9.481774609431103e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   10     240.178       9.475 8.62e-11       0.00742       0.00261  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01778542598010453 max of gamma 0.03745508908814442 var of gamma 9.490337408633817e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   11     240.169       9.471 5.34e-11       0.00238       0.00101  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01777018225834459 max of gamma 0.03745499821937852 var of gamma 9.496843849919956e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   12     240.165       9.469    1e-10      0.000825      0.000417  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01776014251233918 max of gamma 0.03745681942818702 var of gamma 9.501570558447232e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   13     240.165       9.467 7.16e-10      0.000302      0.000178  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017753446071271044 max of gamma 0.03745910096471801 var of gamma 9.50512562167623e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   14     240.166       9.466 1.69e-09      0.000114      7.95e-05  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017748956218914366 max of gamma 0.03746121920641963 var of gamma 9.507858504519896e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   15     240.167       9.465 1.03e-09      4.44e-05      3.74e-05  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017745868563437142 max of gamma 0.03746294560411974 var of gamma 9.509936995805716e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   16     240.168       9.465 5.68e-10      1.79e-05      1.84e-05  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017743723088566813 max of gamma 0.03746428185876362 var of gamma 9.511491033365134e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   17     240.168       9.464  3.8e-10      7.49e-06      1.03e-05  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01774219337742514 max of gamma 0.037465225600897475 var of gamma 9.51267543598613e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   18     240.168       9.464 2.87e-10      3.31e-06       6.6e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017741082599216893 max of gamma 0.03746586436042054 var of gamma 9.513579678951658e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   19     240.169       9.464 2.39e-10      1.56e-06      1.83e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01774040925459173 max of gamma 0.037466653538817236 var of gamma 9.514176573050922e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   20     240.169       9.464  2.1e-10      8.03e-07      1.13e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017739915997928336 max of gamma 0.03746710273030082 var of gamma 9.514581575290438e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   21     240.169       9.464  1.9e-10      4.51e-07      7.68e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773953072402045 max of gamma 0.03746742022082724 var of gamma 9.514906675086745e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   22     240.169       9.464 1.75e-10      2.76e-07      2.93e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017739093735789056 max of gamma 0.03746732786395694 var of gamma 9.515257705637087e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   23     240.169       9.464 1.62e-10      1.84e-07      8.84e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773881489060168 max of gamma 0.037467430252455095 var of gamma 9.515541506150873e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   24     240.168       9.464 1.51e-10       1.3e-07      7.77e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017738577486841163 max of gamma 0.037467406855392606 var of gamma 9.515789951842327e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   25     240.168       9.464 1.43e-10      9.49e-08      2.78e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017738419402724255 max of gamma 0.03746746794549838 var of gamma 9.515978692688588e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   26     240.168       9.464 1.36e-10      7.05e-08      3.71e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773785959055683 max of gamma 0.03746734761923175 var of gamma 9.516814406488339e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   27     240.168       9.463  1.3e-10      5.33e-08      2.25e-05  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773672999041385 max of gamma 0.03746727736897475 var of gamma 9.518778457639347e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   28     240.168       9.463 1.24e-10      4.11e-08      6.66e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773623915237755 max of gamma 0.0374672046297375 var of gamma 9.519586682386351e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   29     240.168       9.463  1.2e-10      3.19e-08      3.06e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017735923866279556 max of gamma 0.03746714022510701 var of gamma 9.520083749167482e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   30     240.168       9.463 1.16e-10      2.47e-08      1.86e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773568504448741 max of gamma 0.03746707584301232 var of gamma 9.520447666340398e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   31     240.168       9.463 1.14e-10       1.9e-08      1.21e-06  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017735495756858198 max of gamma 0.03746701708464934 var of gamma 9.520729295526672e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   32     240.168       9.463 1.11e-10      1.46e-08      8.39e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773534100419377 max of gamma 0.03746696312123808 var of gamma 9.520955755473786e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   33     240.168       9.463 1.09e-10      1.13e-08      6.03e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773521154536271 max of gamma 0.03746691342829916 var of gamma 9.521142807598763e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   34     240.168       9.463 1.08e-10      8.67e-09      4.44e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017735101737378373 max of gamma 0.03746686811856465 var of gamma 9.521299900384247e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   35     240.167       9.463 1.06e-10      6.68e-09      3.45e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773500658435735 max of gamma 0.03746682498028367 var of gamma 9.521434967861063e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   36     240.167       9.463 1.05e-10      5.15e-09      2.76e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773492321828114 max of gamma 0.03746678399878879 var of gamma 9.521552544455488e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   37     240.167       9.463 1.04e-10      3.98e-09      2.23e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734849749913142 max of gamma 0.03746674536412392 var of gamma 9.521655677018222e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   38     240.167       9.463 1.03e-10      3.08e-09      1.83e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773478461859361 max of gamma 0.03746670895898531 var of gamma 9.521746794631965e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   39     240.167       9.463 1.02e-10      2.38e-09      1.51e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773472658597839 max of gamma 0.037466674671838715 var of gamma 9.521827768818264e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   40     240.167       9.463 1.01e-10      1.84e-09      1.24e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734674841796014 max of gamma 0.037466642610490965 var of gamma 9.521899836215718e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   41     240.167       9.463 1.01e-10      1.43e-09      1.03e-07  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734628603491103 max of gamma 0.03746661267747142 var of gamma 9.52196414937246e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   42     240.167       9.463    1e-10       1.1e-09      8.55e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773458711245774 max of gamma 0.037466584658363 var of gamma 9.52202179626705e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   43     240.167       9.463 9.99e-11      8.55e-10      7.17e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734549761809857 max of gamma 0.037466558428463595 var of gamma 9.522073654073128e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   44     240.167       9.463 9.95e-11      6.63e-10      6.07e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734516020712767 max of gamma 0.03746653381745176 var of gamma 9.522120489725159e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   45     240.167       9.463 9.91e-11      5.14e-10      5.17e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734485450289952 max of gamma 0.037466510697536586 var of gamma 9.522162928632329e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   46     240.167       9.463 9.88e-11      3.99e-10      4.43e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773445767149553 max of gamma 0.03746648894800601 var of gamma 9.52220151018525e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   47     240.167       9.463 9.86e-11       3.1e-10      3.81e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734432361251107 max of gamma 0.0374664684528873 var of gamma 9.522236685702889e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   48     240.167       9.463 9.83e-11       2.4e-10      3.34e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.017734409154540227 max of gamma 0.03746644883973951 var of gamma 9.522268944488775e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   49     240.167       9.463 9.81e-11      1.87e-10      2.95e-08  0.000      0.018     1.36
# Accept the step
# ====================================================
# STEP 1 : Nominal trajectory update
# STEP 2 : Lipschitz constant estimation
# mean of gamma 0.01773438782133553 max of gamma 0.03746643008028744 var of gamma 9.522298600603205e-05
# STEP 3 : Funnel update via SDP
# STEP 4 : update beta for invariance
# iter| traj_cost | funl_cost |   vc   |   Delta_T   |   Delta_F   |e_prop|mean_gamma|max_beta
#   50     240.167       9.463 9.79e-11      1.45e-10      2.62e-08  0.000      0.018     1.36
# Accept the step

# %%
traj_diff_list = [history[i]['traj_diff'] for i in range(idx_iter+1)]
funl_diff_list = [history[i]['funl_diff'] for i in range(idx_iter+1)]

# %%
i_index = np.array([i+1 for i in range(idx_iter+1)])
fS = 20
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(i_index,traj_diff_list,'o-')
plt.plot(i_index,i_index*0+tol_traj,'--')
plt.xlabel('iteration number',fontsize=fS,fontname='Times New Roman')
plt.ylabel(r'$\Delta_T$',fontsize=fS,fontname='Times New Roman')
plt.yscale('log')
# plt.ylim([10**(-6), 10**(4)])
plt.grid(True)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# plt.legend(fontsize=fS)
plt.subplot(122)
plt.plot(i_index,funl_diff_list,'o-')
plt.plot(i_index,i_index*0+tol_funnel,'--',label="tolerance")
plt.xlabel('iteration number',fontsize=fS,fontname='Times New Roman')
plt.ylabel(r'$\Delta_F$',fontsize=fS,fontname='Times New Roman')
plt.yscale('log')
# plt.ylim([10**(-6), 10**(4)])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rcParams["font.family"] = "Times New Roman"
plt.legend(fontsize=fS)
plt.grid(True)
# plt.savefig('../images/convergence_result.pdf')

# %% [markdown]
# # Evaluate the generated traj and funl

# %%
from utils.utils_alg import forward_full_with_K,get_sample_trajectory
import scipy

# %%
xbar = history[-1]['x']
ubar = history[-1]['u']
Qbar = history[-1]['Q']
Ybar = history[-1]['Y']
Kbar = history[-1]['K']

# %% [markdown]
# # Obtain nominal traj without the funnel

# %%
traj_solver= PTR('unicycle',N,tf,30,myModel,myCost,myConst,
              w_c=1,w_vc=1e3,w_tr=1e1,tol_vc=1e-6,tol_tr=1e-4,verbosity=True)
_,_,xnom,unom,total_num_iter,flag_boundary,_,_,_ = traj_solver.run(x0,u0,xi,xf)
# Out:
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        bounary
# 1           5918.533          83.340      5           83.5        -4.92e+03   10.000      0( 5)
# 2           915.754           128.182     2.88e-09    78.8        5e+03       10.000      0(2.28)
# 3           266.635           196.911     2.53e-10    6.97        649         10.000      0(0.732)
# 4           218.399           206.527     2.39e-09    1.19        48.2        10.000      0(0.0864)
# 5           209.577           208.977     3.74e-10    0.06        8.82        10.000      0(0.00239)
# 6           208.509           208.248     4.5e-10     0.0262      1.07        10.000      1(0.000376)
# 7           207.905           207.791     9.81e-10    0.0114      0.604       10.000      1(0.000135)
# 8           207.724           207.702     1.28e-09    0.00221     0.181       10.000      1(5.41e-05)
# 9           207.693           207.687     1.09e-09    0.0006      0.0305      10.000      1(1.48e-05)
# 10          207.685           207.683     9.92e-10    0.000174    0.0086      10.000      1(4.37e-06)
# 11          207.682           207.682     9.42e-10    5.37e-05    0.00257     10.000      1(1.33e-06)
# SUCCEESS: virtual control and trust region < tol

# %% [markdown]
# # Sample from initial set

# %%
x0_sample = []
num_sample = 100
idx = 0
for i in range(num_sample) :
    z = np.random.randn(ix)
    z = z / np.linalg.norm(z)
    x_s = xbar[idx] + scipy.linalg.sqrtm(Qbar[idx])@z
    x0_sample.append(x_s)

# %%
tsam,xsam,usam,wsam = get_sample_trajectory(xi,x0_sample,xbar,ubar,Qbar,Ybar,myModel,N,ix,iu,iw,delT,flag_noise=True,discrete=True)

# %%
fS = 15
plt.figure(0,figsize=(7,7))
plot_traj_set(xbar,ubar,c_list,H_list,Qbar,xi=xi,xf=xf,Qi=Qini,Qf=Qf,plt=plt)
# plt.plot(xnom[:,0],xnom[:,1],'-.',color='tab:brown',label='traj w/o funnel')
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('../images/first_iteration/proposed.pdf')

# %%
fS = 15
plt.figure(0,figsize=(7,7))
for xsam_e in xsam :
    plt.plot(xsam_e[:,0], xsam_e[:,1],'-',markersize=4.0, linewidth=1.0,alpha=0.4,color='tab:purple')
plot_traj_set(xbar,ubar,c_list,H_list,Qbar,xi=xi,xf=xf,Qi=Qini,Qf=Qf,plt=plt,flag_label=True)
plt.plot(1e3,1e3,'-',color='tab:purple',label='samples')
plt.plot(xnom[:,0],xnom[:,1],'-.',color='tab:brown',label='traj w/o funnel')
plt.legend(fontsize=fS)
plt.grid(True)
plt.rcParams["font.family"] = "Times New Roman"
# plt.savefig('../images/traj_result.pdf')

# %%
fS = 20
plt.figure(0,figsize=(10,5))
alpha = 0.5
t_index = np.array(range(N+1))*delT
for i in range(num_sample) :
    tsam_e = tsam[i]
    xsam_e = xsam[i]
    usam_e = usam[i]
#     plot_state_input(tsam_e,xsam_e,usam_e,None,None,N,delT,alpha,plt,flag_step=False)

    plt.subplot(121)
    plt.plot(tsam_e, usam_e[:,0],color='tab:purple',alpha=alpha,linewidth=1.0)
    plt.subplot(122)
    plt.plot(tsam_e, usam_e[:,1],color='tab:purple',alpha=alpha,linewidth=1.0)
plt.subplot(121)
plt.plot(tsam_e, usam_e[:,0]*0+myConst.vmax,'-.',color='tab:red',alpha=1.0,linewidth=2.0,label='limit')
plt.step(t_index, [*ubar[:N,0],ubar[N-1,0]],'--',color='tab:orange',alpha=1.0,where='post',linewidth=2.0,label='nominal')
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('$u_v$ (m/s)', fontsize = fS)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.axis([0.0, tf, -0.5, 4.5])
plt.grid(True)
plt.subplot(122)
plt.plot(tsam_e, usam_e[:,1]*0+myConst.wmax,'-.',color='tab:red',alpha=1.0,linewidth=2.0)
plt.plot(tsam_e, usam_e[:,1]*0+myConst.wmin,'-.',color='tab:red',alpha=1.0,linewidth=2.0,label='limit')
plt.step(t_index, [*ubar[:N,1],ubar[N-1,1]],'--',color='tab:orange',alpha=1.0,where='post',linewidth=2.0,label='nominal')
plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('$u_{\Theta}$ (rad/s)', fontsize = fS)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.axis([0.0, tf, -3, 3])
plt.legend(fontsize=fS)
plt.rcParams["font.family"] = "Times New Roman"
plt.grid(True)
# plt.savefig('../images/input_result.pdf')

# %%
# fS = 20
# plt.figure(0,figsize=(10,5))
# alpha = 0.5
# t_index = np.array(range(N+1))*delT
# for i in range(num_sample) :
#     tsam_e = tsam[i]
#     xsam_e = xsam[i]
#     wsam_e = wsam[i]
# #     plot_state_input(tsam_e,xsam_e,usam_e,None,None,N,delT,alpha,plt,flag_step=False)
#     plt.subplot(121)
#     plt.plot(tsam_e, wsam_e[:,0],color='tab:purple',alpha=alpha,linewidth=1.0)
#     plt.subplot(122)
#     plt.plot(tsam_e, wsam_e[:,1],color='tab:purple',alpha=alpha,linewidth=1.0)
# plt.subplot(121)
# plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
# plt.xlabel('time (s)', fontsize = fS)
# plt.ylabel('w1 (m)', fontsize = fS)
# plt.axis([0.0, tf, -2, 2])
# plt.subplot(122)
# plt.plot(1e3, 1e3,'-',color='tab:purple',alpha=1.0,linewidth=1.0,label='samples')
# plt.xlabel('time (s)', fontsize = fS)
# plt.ylabel('w2 (m)', fontsize = fS)
# plt.axis([0.0, tf, -2, 2])
# plt.legend(fontsize=fS)
# plt.rcParams["font.family"] = "Times New Roman"
# # plt.savefig('../images/disturbance.pdf')
